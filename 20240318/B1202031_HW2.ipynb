# %%
a = 'C,B,A'
b=['F','G','H']
c = a.split(',')
d=c+b
d[0]='K'
print(d[2])
del d[2]
del d[1:4]
d.append('U')
print(d)
# Out:
# A
# ['K', 'H', 'U']

# %%
a=list(input('輸入一個八位數的數字:'))
print(a[4])
# Out:
# 輸入一個八位數的數字:12356456
# 6

# %%
a='My ID is B1202031'
b=a.split(' ')
print(len(b))
print(len(b[3]))
# Out:
# 4
# 8

# %%
a="I'm a student"
b=a.split(' ')
c=b[0]
d=c.split("\'")
print(d[1])
# Out:
# m
