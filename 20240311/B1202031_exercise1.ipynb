# %%
a='''長庚大學
醫學系
李宛虹'''
print(a)
# Out:
# 長庚大學
# 醫學系
# 李宛虹

# %%
a=3
b=5
print(a**b)
# Out:
# 243

# %%
a=3
b=5
a/=b
print(a)
# Out:
# 0.6

# %% [markdown]
# 20240311作業
#
# a='10'
# print(type(int(a)))
# print(type(float(a)))
# print(type(str(a)))
#
# /type 可以不用打
# /int 變成整數
# /float 變成浮點數
# /str 變成字串
#
# print(10/2) 5.0
# print(10//2) 5
#
# a+=1
